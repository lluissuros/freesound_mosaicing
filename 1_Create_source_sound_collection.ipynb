# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
import os
import pandas as pd
import numpy as np
import freesound
from IPython.display import display

FREESOUND_API_KEY = 's9xV21k899aPetFLLLj7IQjq2hCprXG0IqymUEy1'  # my api key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound, file_path = "files/"): 
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = file_path + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    {
        'query': 'dog bark',
        'filter': None,
        'num_results': 20, 
    },
    {
        'query': 'percussion sounds',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'vocals',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 337101 [1/60]
# Downloading sound with id 327666 [2/60]
# Downloading sound with id 413758 [3/60]
# Downloading sound with id 163459 [4/60]
# Downloading sound with id 456943 [5/60]
# Downloading sound with id 418105 [6/60]
# Downloading sound with id 420447 [7/60]
# Downloading sound with id 236011 [8/60]
# Downloading sound with id 115536 [9/60]
# Downloading sound with id 160092 [10/60]
# Downloading sound with id 180977 [11/60]
# Downloading sound with id 157322 [12/60]
# Downloading sound with id 425904 [13/60]
# Downloading sound with id 118961 [14/60]
# Downloading sound with id 386766 [15/60]
# Downloading sound with id 199261 [16/60]
# Downloading sound with id 277058 [17/60]
# Downloading sound with id 446593 [18/60]
# Downloading sound with id 408810 [19/60]
# Downloading sound with id 424593 [20/60]
# Downloading sound with id 124100 [21/60]
# Downloading sound with id 57040 [22/60]
# Downloading sound with id 260468 [23/60]
# Downloading sound with id 183115 [24/60]
# Downloading sound with id 338747 [25/60]
# Downloading sound with id 424372 [26/60]
# Downloading sound with id 264173 [27/60]
# Downloading sound with id 31061 [28/60]
# Downloading sound with id 207913 [29/60]
# Downloading sound with id 249971 [30/60]
# Downloading sound with id 193977 [31/60]
# Downloading sound with id 139500 [32/60]
# Downloading sound with id 111163 [33/60]
# Downloading sound with id 65688 [34/60]
# Downloading sound with id 329924 [35/60]
# Downloading sound with id 345679 [36/60]
# Downloading sound with id 63240 [37/60]
# Downloading sound with id 396226 [38/60]
# Downloading sound with id 399329 [39/60]
# Downloading sound with id 347121 [40/60]
# Downloading sound with id 315688 [41/60]
# Downloading sound with id 75509 [42/60]
# Downloading sound with id 33753 [43/60]
# Downloading sound with id 432875 [44/60]
# Downloading sound with id 272029 [45/60]
# Downloading sound with id 87649 [46/60]
# Downloading sound with id 88159 [47/60]
# Downloading sound with id 251683 [48/60]
# Downloading sound with id 417506 [49/60]
# Downloading sound with id 88402 [50/60]
# Downloading sound with id 150505 [51/60]
# Downloading sound with id 166161 [52/60]
# Downloading sound with id 180343 [53/60]
# Downloading sound with id 166357 [54/60]
# Downloading sound with id 215363 [55/60]
# Downloading sound with id 112582 [56/60]
# Downloading sound with id 87697 [57/60]
# Downloading sound with id 181881 [58/60]
# Downloading sound with id 256359 [59/60]
# Downloading sound with id 254275 [60/60]
# Saved DataFrame with 60 entries! dataframe.csv
#     freesound_id                                            license  \
# 0         337101  http://creativecommons.org/publicdomain/zero/1.0/
# 1         327666     http://creativecommons.org/licenses/by-nc/3.0/
# 2         413758  http://creativecommons.org/publicdomain/zero/1.0/
# 3         163459  http://creativecommons.org/publicdomain/zero/1.0/
# 4         456943  http://creativecommons.org/publicdomain/zero/1.0/
# 5         418105        http://creativecommons.org/licenses/by/3.0/
# 6         420447  http://creativecommons.org/publicdomain/zero/1.0/
# 7         236011     http://creativecommons.org/licenses/by-nc/3.0/
# 8         115536        http://creativecommons.org/licenses/by/3.0/
# 9         160092        http://creativecommons.org/licenses/by/3.0/
# 10        180977  http://creativecommons.org/publicdomain/zero/1.0/
# 11        157322        http://creativecommons.org/licenses/by/3.0/
# 12        425904  http://creativecommons.org/publicdomain/zero/1.0/
# 13        118961  http://creativecommons.org/publicdomain/zero/1.0/
# 14        386766  http://creativecommons.org/publicdomain/zero/1.0/
# 15        199261  http://creativecommons.org/publicdomain/zero/1.0/
# 16        277058  http://creativecommons.org/publicdomain/zero/1.0/
# 17        446593  http://creativecommons.org/publicdomain/zero/1.0/
# 18        408810     http://creativecommons.org/licenses/by-nc/3.0/
# 19        424593  http://creativecommons.org/publicdomain/zero/1.0/
# 20        124100  http://creativecommons.org/publicdomain/zero/1.0/
# 21         57040        http://creativecommons.org/licenses/by/3.0/
# 22        260468  http://creativecommons.org/publicdomain/zero/1.0/
# 23        183115        http://creativecommons.org/licenses/by/3.0/
# 24        338747  http://creativecommons.org/publicdomain/zero/1.0/
# 25        424372  http://creativecommons.org/publicdomain/zero/1.0/
# 26        264173        http://creativecommons.org/licenses/by/3.0/
# 27         31061     http://creativecommons.org/licenses/by-nc/3.0/
# 28        207913        http://creativecommons.org/licenses/by/3.0/
# 29        249971        http://creativecommons.org/licenses/by/3.0/
# 30        193977  http://creativecommons.org/publicdomain/zero/1.0/
# 31        139500  http://creativecommons.org/publicdomain/zero/1.0/
# 32        111163        http://creativecommons.org/licenses/by/3.0/
# 33         65688        http://creativecommons.org/licenses/by/3.0/
# 34        329924        http://creativecommons.org/licenses/by/3.0/
# 35        345679        http://creativecommons.org/licenses/by/3.0/
# 36         63240     http://creativecommons.org/licenses/by-nc/3.0/
# 37        396226  http://creativecommons.org/publicdomain/zero/1.0/
# 38        399329  http://creativecommons.org/publicdomain/zero/1.0/
# 39        347121  http://creativecommons.org/publicdomain/zero/1.0/
# 40        315688  http://creativecommons.org/publicdomain/zero/1.0/
# 41         75509  http://creativecommons.org/publicdomain/zero/1.0/
# 42         33753  http://creativecommons.org/publicdomain/zero/1.0/
# 43        432875        http://creativecommons.org/licenses/by/3.0/
# 44        272029  http://creativecommons.org/publicdomain/zero/1.0/
# 45         87649  http://creativecommons.org/publicdomain/zero/1.0/
# 46         88159  http://creativecommons.org/licenses/sampling+/...
# 47        251683  http://creativecommons.org/publicdomain/zero/1.0/
# 48        417506        http://creativecommons.org/licenses/by/3.0/
# 49         88402  http://creativecommons.org/publicdomain/zero/1.0/
# 50        150505  http://creativecommons.org/publicdomain/zero/1.0/
# 51        166161  http://creativecommons.org/publicdomain/zero/1.0/
# 52        180343        http://creativecommons.org/licenses/by/3.0/
# 53        166357        http://creativecommons.org/licenses/by/3.0/
# 54        215363  http://creativecommons.org/publicdomain/zero/1.0/
# 55        112582     http://creativecommons.org/licenses/by-nc/3.0/
# 56         87697  http://creativecommons.org/licenses/sampling+/...
# 57        181881        http://creativecommons.org/licenses/by/3.0/
# 58        256359        http://creativecommons.org/licenses/by/3.0/
# 59        254275     http://creativecommons.org/licenses/by-nc/3.0/
#
#                                                  name  \
# 0                           Group_of_Dogs_Barking.WAV
# 1                                        Dog Bark.wav
# 2                                      dogbarking.mp3
# 3                  LBS_FX DOG Small Alert Bark001.wav
# 4                         Blossom Bark  29sec mix.wav
# 5                                   single dog bark 3
# 6                                       Barking 4.wav
# 7                  Jazz the Dog Howl & Bark (136).wav
# 8                                       Two Barks.wav
# 9                                          Dog bark 1
# 10                                        Barking Dog
# 11                 Dog Bark Staffordshire Bullterrier
# 12                                         BarkingDog
# 13                                     Dog Bark 1.wav
# 14                                    Dog_Barking.wav
# 15                    A dog barking (close recording)
# 16                                    Single Dog Bark
# 17                                        Barking Dog
# 18                                       Dog Bark.wav
# 19                                    Dog Barking.m4a
# 20                                       Ch Sound.wav
# 21                                 suctioncupkick.wav
# 22                 electribe-kicks slice 0A [A#4].wav
# 23                                   prc_appet909.wav
# 24           Perc. coffee tin 04 muted March 2016.wav
# 25                             percussion sound 2.wav
# 26                                 original sound.wav
# 27                                       Sound 13.wav
# 28                                      Bandpass snap
# 29                                  Short_sound_3.wav
# 30                                   Knife Hit 25.wav
# 31                                         various 28
# 32                               firecracker_coke.wav
# 33                                     toiletseat.wav
# 34                               Knocking on Door.wav
# 35                                       wood hit.wav
# 36  ac004 tambourine one hand shot with pre sound.wav
# 37       click/hi hat sound (sample off of Flume).wav
# 38   plastic - bubble wrap - shaker type sound 01.wav
# 39                    HeavyHot Snare - Nova Sound.wav
# 40                                             ououou
# 41                                           base.mp3
# 42                                           FUGg.wav
# 43                                       LFS_Vox8.wav
# 44                                         Male cough
# 45                                              e.wav
# 46                                        vocal A.wav
# 47                                            Nah.wav
# 48                                        jucuzzi.wav
# 49                                     aaaaa_GNAS.wav
# 50                                       Huh? - Vocal
# 51                                   Vocal_male_1.wav
# 52                              Short scared scream 1
# 53               "Alarm" (Male Voice through Speaker)
# 54                                           bee2.wav
# 55                                              a.wav
# 56                                              a.wav
# 57                                         Ay Vox cut
# 58                      Robotic Vocal saying - Groovy
# 59                                   Airy vocal cough
#
#                            path  \
# 0   files/337101_3474310-hq.ogg
# 1   files/327666_5632380-hq.ogg
# 2   files/413758_7958399-hq.ogg
# 3   files/163459_2965892-hq.ogg
# 4   files/456943_3194431-hq.ogg
# 5   files/418105_6078577-hq.ogg
# 6   files/420447_2402876-hq.ogg
# 7    files/236011_180659-hq.ogg
# 8   files/115536_1956076-hq.ogg
# 9   files/160092_2888453-hq.ogg
# 10  files/180977_3370987-hq.ogg
# 11       files/157322_58-hq.ogg
# 12  files/425904_8563244-hq.ogg
# 13  files/118961_1990695-hq.ogg
# 14  files/386766_5768130-hq.ogg
# 15  files/199261_1661766-hq.ogg
# 16  files/277058_4486188-hq.ogg
# 17  files/446593_9134393-hq.ogg
# 18  files/408810_7208336-hq.ogg
# 19  files/424593_8518940-hq.ogg
# 20  files/124100_2219481-hq.ogg
# 21      files/57040_4948-hq.ogg
# 22  files/260468_2127539-hq.ogg
# 23  files/183115_2394245-hq.ogg
# 24  files/338747_5450487-hq.ogg
# 25  files/424372_7099958-hq.ogg
# 26  files/264173_2750665-hq.ogg
# 27     files/31061_33110-hq.ogg
# 28    files/207913_19852-hq.ogg
# 29    files/249971_97763-hq.ogg
# 30  files/193977_3022224-hq.ogg
# 31  files/139500_1951924-hq.ogg
# 32     files/111163_4948-hq.ogg
# 33      files/65688_4948-hq.ogg
# 34  files/329924_2812020-hq.ogg
# 35  files/345679_2775767-hq.ogg
# 36    files/63240_321967-hq.ogg
# 37  files/396226_3202651-hq.ogg
# 38  files/399329_5923045-hq.ogg
# 39   files/347121_369949-hq.ogg
# 40  files/315688_3442171-hq.ogg
# 41    files/75509_818377-hq.ogg
# 42    files/33753_213746-hq.ogg
# 43  files/432875_4157918-hq.ogg
# 44  files/272029_5165013-hq.ogg
# 45    files/87649_664547-hq.ogg
# 46   files/88159_1269037-hq.ogg
# 47  files/251683_1730960-hq.ogg
# 48  files/417506_1453392-hq.ogg
# 49   files/88402_1097185-hq.ogg
# 50  files/150505_1883289-hq.ogg
# 51  files/166161_2104797-hq.ogg
# 52  files/180343_2888453-hq.ogg
# 53    files/166357_71257-hq.ogg
# 54   files/215363_950925-hq.ogg
# 55  files/112582_1813144-hq.ogg
# 56   files/87697_1265297-hq.ogg
# 57  files/181881_3172867-hq.ogg
# 58  files/256359_4062622-hq.ogg
# 59  files/254275_4062622-hq.ogg
#
#                                                  tags           username
# 0   [growling, growl, Group, barking, animal, pet,...            ivolipa
# 1   [bellow, barking, intimidating, angrily, bark,...  Juan_Merie_Venter
# 2                      [barking, Dog, dog, bark, big]      lala_davis554
# 3              [Chihuahua, FX, Dog, dog, Small, bark]    LittleBigSounds
# 4    [howl, bark, dog, Dog, barking, German-shepherd]            Zajjman
# 5   [bark, animal, dog, pet, barking, growl, growl...        crazymonke9
# 6   [pets, howl, wolves, wolf, dog, animals, snarl...       Mrthenoronha
# 7   [Barking, Jazz, Barks, Dog, Howling, Wolf, Ani...      delphidebrain
# 8   [animal, bark, barking, dog, effects, noise, s...             Puniho
# 9                           [average-size, bark, Dog]        jorickhoofd
# 10                  [bark, happy, loud, dog, barking]        Suprasummun
# 11  [sennheiser, sound-devices, dog, m-s, stafford...              Anton
# 12                      [dog, bark, InterSpecies2018]         NatalieTre
# 13                                [animal, bark, dog]            esperri
# 14                               [barking, dog, bark]             ken788
# 15  [moan, blume, barking, usa, grunting, felix, d...        felix.blume
# 16  [animal, pet, dog, public-domain, woof, single...         kwahmah_02
# 17                                [Animal, Dog, Bark]        Nicolas4677
# 18  [bark, animal, dog, dog-barking, pet, barking,...             Okuhle
# 19                               [Barking, Dog, Bark]     Daniela-Santos
# 20  [beatboxing, connersaw8, mouth, percussion, so...         connersaw8
# 21    [dangerous, foley, kitchen, percussion, sounds]     NoiseCollector
# 22  [bd, groovebox, presets, drum, bassdrum, percu...        soneproject
# 23  [perc, hits, drums, house, Percussion, music, ...               DWSD
# 24  [sample-pack, sampling, sample, raw, Sampler, ...        cabled_mess
# 25                     [percussive, percussion, perc]            Elnosos
# 26  [perc, one-shot, hit, sfx, percussion, snaree,...        GabrieleKkj
# 27  [box, bridge, drum, industrial, metal, percuss...          scuzzpuck
# 28          [percussion, imposcar, softsynth, gforce]           altemark
# 29  [noise, AM, Twente-University, short-wave, per...           AlienXXX
# 30  [drum, metal, silverware, metallic, percussion...        potentjello
# 31                          [snap, percussion, click]           arseniiv
# 32                     [firecracker, hit, percussion]     NoiseCollector
# 33                         [percussion, seat, toilet]     NoiseCollector
# 34  [hit, knock, door, wooden, rythmic, knocking, ...            Uzbazur
# 35  [impact, industrial, hit, high-quality, metal,...           VitaWrap
# 36        [drums, percussion, percussive, tambourine]        Robinhood76
# 37  [click, hi-hat, drums, percussion, high-hat, b...           lavaande
# 38  [packing-material, packing, percussion, bubble...          Anthousai
# 39  [Flames, Burning, Fire, Fireworks, Percussion,...             Fiditg
# 40  [one-shot-sample, spoken-word, vocal-sample, v...          Roses1401
# 41  [acapella, acapellas, akapella, base, bass, ha...              TiBRo
# 42  [bcjordan, fuck, jerk, speech, vocal, vocals, ...           bcjordan
# 43  [scream, male, vocals, stupid, vocal, voice, s...            xtrgamr
# 44  [cough, vocal, voice, vocals, human, sounds, m...         aldenroth2
# 45                        [catalan, e, vocals, voice]            vallver
# 46                                         [a, vocal]             tajada
# 47  [henriquedesa, voice, vocalizations, vocal, hu...       henriquedesa
# 48                             [human, voice, sample]         Xcreenplay
# 49      [68880, a, digital, parla, tractament, vocal]     guillemnicolau
# 50     [boy, vocale, huh, confused, vocal, guy, male]          davdud101
# 51                           [voice, male, eh, vocal]             Adam_N
# 52  [anxious, male, fearful, scared, alarmed, afra...        jorickhoofd
# 53  [male, alarm, accent, robot, echo, warning, sp...            qubodup
# 54                                 [voice, buzz, bee]           Reitanna
# 55                                       [a, spanish]             kosden
# 56                                                [a]           ruben226
# 57        [FX, effect, Vocal, JLee, Vox, 4x4-records]             Goup_1
# 58  [droid, dance, Countdown, Synthesizer, Speech,...          Jagadamba
# 59              [voice, airy, coughing, cough, vocal]          Jagadamba

# %%
#MY OWN CONTRIBUTION

# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
sounds_to_save_path_harmony = 'deliverables/harmony/'
sounds_to_save_path_drums = 'deliverables/drums/'

DATAFRAME_FILENAME_HARMONY = 'deliverables/dataframes/dataframe_harmony.csv'
DATAFRAME_FILENAME_DRUMS =  'deliverables/dataframes/dataframe_drums.csv'

# Build our collection of sounds
freesound_queries_harmony = [
    {
        'query': 'quartet',
        'filter': 'duration:[0 TO 30]',
        'num_results': 20, 
    },
    {
        'query': 'strings',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    },
    {
        'query': 'marimba',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    },
    {
        'query': 'pan flute',
        'filter': 'duration:[0 TO 4]',
        'num_results': 5, 
    },
    {
        'query': 'flute',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    },
    {
        'query': 'trumpet',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    },
    {
        'query': 'oboe',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    },
    {
        'query': 'cello',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    }  
]


freesound_queries_drums = [
    {
        'query': 'drums',
        'filter': 'duration:[0 TO 2]',
        'num_results': 30, 
    },
    {
        'query': 'clapping',
        'filter': 'duration:[0 TO 2]',
        'num_results': 30, 
    }
]


def build_sound_collection(freesound_queries, sound_files_path, dataframe_filename):
    # Do all queries and concatenate the results in a single list of sounds
    sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

    # Download the sounds and save them to FILES_DIR folder
    for count, sound in enumerate(sounds):
        print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
        retrieve_sound_preview(sound, sound_files_path)

    # Make a Pandas DataFrame with the metadata of our sound collection and save it
    df =  pd.DataFrame([make_pandas_record(s, sound_files_path) for s in sounds])
    df.to_csv(dataframe_filename)
    print('Saved DataFrame with {0} entries! {1}'.format(len(df), dataframe_filename))

    # Show the contents of our DataFrame (the metadata of our source collection)
    print(df.head(5))
    return df, sounds



df, sounds = build_sound_collection(freesound_queries_harmony, sounds_to_save_path_harmony, DATAFRAME_FILENAME_HARMONY)
#build_sound_collection(freesound_queries_drums, sounds_to_save_path_drums, DATAFRAME_FILENAME_DRUMS)
# Out:
# Downloading sound with id 44845 [1/162]
# Downloading sound with id 429954 [2/162]
# Downloading sound with id 361680 [3/162]
# Downloading sound with id 220449 [4/162]
# Downloading sound with id 438907 [5/162]
# Downloading sound with id 268603 [6/162]
# Downloading sound with id 31992 [7/162]
# Downloading sound with id 377029 [8/162]
# Downloading sound with id 220377 [9/162]
# Downloading sound with id 442291 [10/162]
# Downloading sound with id 412357 [11/162]
# Downloading sound with id 337895 [12/162]
# Downloading sound with id 342016 [13/162]
# Downloading sound with id 161167 [14/162]
# Downloading sound with id 121023 [15/162]
# Downloading sound with id 121031 [16/162]
# Downloading sound with id 257528 [17/162]
# Downloading sound with id 153644 [18/162]
# Downloading sound with id 134013 [19/162]
# Downloading sound with id 42710 [20/162]
# Downloading sound with id 395155 [21/162]
# Downloading sound with id 395156 [22/162]
# Downloading sound with id 395158 [23/162]
# Downloading sound with id 395159 [24/162]
# Downloading sound with id 395161 [25/162]
# Downloading sound with id 395162 [26/162]
# Downloading sound with id 395164 [27/162]
# Downloading sound with id 395165 [28/162]
# Downloading sound with id 395166 [29/162]
# Downloading sound with id 395167 [30/162]
# Downloading sound with id 395170 [31/162]
# Downloading sound with id 395173 [32/162]
# Downloading sound with id 395154 [33/162]
# Downloading sound with id 249195 [34/162]
# Downloading sound with id 151817 [35/162]
# Downloading sound with id 241337 [36/162]
# Downloading sound with id 190520 [37/162]
# Downloading sound with id 160243 [38/162]
# Downloading sound with id 167724 [39/162]
# Downloading sound with id 55306 [40/162]
# Downloading sound with id 372367 [41/162]
# Downloading sound with id 337909 [42/162]
# Downloading sound with id 255678 [43/162]
# Downloading sound with id 130527 [44/162]
# Downloading sound with id 373578 [45/162]
# Downloading sound with id 47259 [46/162]
# Downloading sound with id 185833 [47/162]
# Downloading sound with id 455431 [48/162]
# Downloading sound with id 351284 [49/162]
# Downloading sound with id 399197 [50/162]
# Downloading sound with id 197257 [51/162]
# Downloading sound with id 381178 [52/162]
# Downloading sound with id 419242 [53/162]
# Downloading sound with id 186501 [54/162]
# Downloading sound with id 394477 [55/162]
# Downloading sound with id 395502 [56/162]
# Downloading sound with id 25417 [57/162]
# Downloading sound with id 434085 [58/162]
# Downloading sound with id 2342 [59/162]
# Downloading sound with id 10430 [60/162]
# Downloading sound with id 390588 [61/162]
# Downloading sound with id 454613 [62/162]
# Downloading sound with id 444667 [63/162]
# Downloading sound with id 427080 [64/162]
# Downloading sound with id 76470 [65/162]
# Downloading sound with id 410405 [66/162]
# Downloading sound with id 113685 [67/162]
# Downloading sound with id 427567 [68/162]
# Downloading sound with id 107307 [69/162]
# Downloading sound with id 60067 [70/162]
# Downloading sound with id 328971 [71/162]
# Downloading sound with id 121067 [72/162]
# Downloading sound with id 121066 [73/162]
# Downloading sound with id 337980 [74/162]
# Downloading sound with id 23782 [75/162]
# Downloading sound with id 133696 [76/162]
# Downloading sound with id 27170 [77/162]
# Downloading sound with id 427566 [78/162]
# Downloading sound with id 176865 [79/162]
# Downloading sound with id 85790 [80/162]
# Downloading sound with id 179061 [81/162]
# Downloading sound with id 429848 [82/162]
# Downloading sound with id 328857 [83/162]
# Downloading sound with id 427570 [84/162]
# Downloading sound with id 460195 [85/162]
# Downloading sound with id 246979 [86/162]
# Downloading sound with id 441067 [87/162]
# Downloading sound with id 257363 [88/162]
# Downloading sound with id 454703 [89/162]
# Downloading sound with id 390588 [90/162]
# Downloading sound with id 247002 [91/162]
# Downloading sound with id 51194 [92/162]
# Downloading sound with id 258199 [93/162]
# Downloading sound with id 21665 [94/162]
# Downloading sound with id 31511 [95/162]
# Downloading sound with id 337923 [96/162]
# Downloading sound with id 194624 [97/162]
# Downloading sound with id 383152 [98/162]
# Downloading sound with id 57849 [99/162]
# Downloading sound with id 350416 [100/162]
# Downloading sound with id 357360 [101/162]
# Downloading sound with id 48223 [102/162]
# Downloading sound with id 48224 [103/162]
# Downloading sound with id 48225 [104/162]
# Downloading sound with id 16671 [105/162]
# Downloading sound with id 369912 [106/162]
# Downloading sound with id 152575 [107/162]
# Downloading sound with id 70890 [108/162]
# Downloading sound with id 413205 [109/162]
# Downloading sound with id 247172 [110/162]
# Downloading sound with id 441065 [111/162]
# Downloading sound with id 415599 [112/162]
# Downloading sound with id 89754 [113/162]
# Downloading sound with id 258107 [114/162]
# Downloading sound with id 77707 [115/162]
# Downloading sound with id 91343 [116/162]
# Downloading sound with id 70891 [117/162]
# Downloading sound with id 374061 [118/162]
# Downloading sound with id 329349 [119/162]
# Downloading sound with id 10678 [120/162]
# Downloading sound with id 413379 [121/162]
# Downloading sound with id 48226 [122/162]
# Downloading sound with id 449070 [123/162]
# Downloading sound with id 254049 [124/162]
# Downloading sound with id 126409 [125/162]
# Downloading sound with id 337981 [126/162]
# Downloading sound with id 355076 [127/162]
# Downloading sound with id 355138 [128/162]
# Downloading sound with id 22686 [129/162]
# Downloading sound with id 373587 [130/162]
# Downloading sound with id 204179 [131/162]
# Downloading sound with id 83981 [132/162]
# Downloading sound with id 60130 [133/162]
# Downloading sound with id 337899 [134/162]
# Downloading sound with id 121018 [135/162]
# Downloading sound with id 121019 [136/162]
# Downloading sound with id 42239 [137/162]
# Downloading sound with id 195547 [138/162]
# Downloading sound with id 331742 [139/162]
# Downloading sound with id 246887 [140/162]
# Downloading sound with id 357902 [141/162]
# Downloading sound with id 195151 [142/162]
# Downloading sound with id 276051 [143/162]
# Downloading sound with id 247989 [144/162]
# Downloading sound with id 341869 [145/162]
# Downloading sound with id 149904 [146/162]
# Downloading sound with id 256480 [147/162]
# Downloading sound with id 372762 [148/162]
# Downloading sound with id 6 [149/162]
# Downloading sound with id 372710 [150/162]
# Downloading sound with id 380852 [151/162]
# Downloading sound with id 149894 [152/162]
# Downloading sound with id 267712 [153/162]
# Downloading sound with id 148076 [154/162]
# Downloading sound with id 148077 [155/162]
# Downloading sound with id 148078 [156/162]
# Downloading sound with id 13721 [157/162]
# Downloading sound with id 8890 [158/162]
# Downloading sound with id 267643 [159/162]
# Downloading sound with id 153723 [160/162]
# Downloading sound with id 153769 [161/162]
# Downloading sound with id 121023 [162/162]
# Saved DataFrame with 162 entries! deliverables/dataframes/dataframe_harmony.csv
#    freesound_id                                            license  \
# 0         44845        http://creativecommons.org/licenses/by/3.0/
# 1        429954  http://creativecommons.org/publicdomain/zero/1.0/
# 2        361680        http://creativecommons.org/licenses/by/3.0/
# 3        220449  http://creativecommons.org/publicdomain/zero/1.0/
# 4        438907     http://creativecommons.org/licenses/by-nc/3.0/
#
#                                      name  \
# 0               string_quartet_stack1.aif
# 1                                 Strings
# 2  horncall_haydn31_hornsignal_Dmajor.wav
# 3                          futurist03.wav
# 4                          Tuning quartet
#
#                                          path  \
# 0     deliverables/harmony/44845_13258-hq.ogg
# 1  deliverables/harmony/429954_1691177-hq.ogg
# 2  deliverables/harmony/361680_6629901-hq.ogg
# 3  deliverables/harmony/220449_4070508-hq.ogg
# 4   deliverables/harmony/438907_520316-hq.ogg
#
#                                                 tags           username
# 0  [atmosphere, cluster, dark, drone, fx, horror,...      thanvannispen
# 1                  [quartet, cello, Strings, violin]      MaxLandergard
# 2  [heroic, D-major, quartet, haydn, fanfare, hun...             TaranP
# 3                  [Russolo, futurist, Intonarumori]        KFerentchak
# 4  [tune, soundscape, piano, ambience, music, orc...  arnaud coutancier

# %%
sounds
# Out:
# [<Sound: id="44845", name="string_quartet_stack1.aif">,
#  <Sound: id="429954", name="Strings">,
#  <Sound: id="361680", name="horncall_haydn31_hornsignal_Dmajor.wav">,
#  <Sound: id="220449", name="futurist03.wav">,
#  <Sound: id="438907", name="Tuning quartet">,
#  <Sound: id="268603", name="ThereminQuartetLoop.wav">,
#  <Sound: id="31992", name="Out of Tune Quartet.wav">,
#  <Sound: id="377029", name="090812 - Rijeka - Pavlinski Trg - Quartet Veljak 3.wav">,
#  <Sound: id="220377", name="Intonomuri_Documentation_02.wav">,
#  <Sound: id="442291", name="string quartet tuning up.wav">,
#  <Sound: id="412357", name="horn lilt 1.wav">,
#  <Sound: id="337895", name="30Strings.wav">,
#  <Sound: id="342016", name="FM Strings A4">,
#  <Sound: id="161167", name="Industrial_Strings_Loop_Noise.aif">,
#  <Sound: id="121023", name="128 link strings.wav">,
#  <Sound: id="121031", name="130 strings ensemble 2.wav">,
#  <Sound: id="257528", name="violin01.wav">,
#  <Sound: id="153644", name="Viola  Non-Vibrato Double Strings Pizzicato 1">,
#  <Sound: id="134013", name="Pick on strings">,
#  <Sound: id="42710", name="01-synSTRINGS90s-¬SW.aif">,
#  <Sound: id="395155", name="Live_LA Strings 009.wav">,
#  <Sound: id="395156", name="Live_LA Strings 029.wav">,
#  <Sound: id="395158", name="Live_LA Strings 023.wav">,
#  <Sound: id="395159", name="Live_LA Strings 024.wav">,
#  <Sound: id="395161", name="Live_LA Strings 022.wav">,
#  <Sound: id="395162", name="Live_LA Strings 027.wav">,
#  <Sound: id="395164", name="Live_LA Strings 025.wav">,
#  <Sound: id="395165", name="Live_LA Strings 026.wav">,
#  <Sound: id="395166", name="Live_LA Strings 014.wav">,
#  <Sound: id="395167", name="Live_LA Strings 013.wav">,
#  <Sound: id="395170", name="Live_LA Strings 018.wav">,
#  <Sound: id="395173", name="Live_LA Strings 015.wav">,
#  <Sound: id="395154", name="Live_LA Strings 010.wav">,
#  <Sound: id="249195", name="swelling strings bpm 160 key c.wav">,
#  <Sound: id="151817", name="String 002 Chord.wav">,
#  <Sound: id="241337", name="Guitar String Slide Noise">,
#  <Sound: id="190520", name="Strings trio hit2.wav">,
#  <Sound: id="160243", name="4247 CFstgsPR2(A2)©SW.aif">,
#  <Sound: id="167724", name="_stezzer_strings.wav">,
#  <Sound: id="55306", name="Old Strings.wav">,
#  <Sound: id="372367", name="Tension Strings C Sharp">,
#  <Sound: id="337909", name="81Marimba.wav">,
#  <Sound: id="255678", name="Marimba A6">,
#  <Sound: id="130527", name="c#2.WAV">,
#  <Sound: id="373578", name="Marimba - B5 (Marimba_hit_Outrigger_B4_loud_01.wav)">,
#  <Sound: id="47259", name="mar.gliss.resbars.damp.buzz1.wav">,
#  <Sound: id="185833", name="Marimba note struck">,
#  <Sound: id="455431", name="07303 marimbic simple advance ding.wav">,
#  <Sound: id="351284", name="Incoming call - Marimba ringtone sound">,
#  <Sound: id="399197", name="Marimba1 Classic Ascending">,
#  <Sound: id="197257", name="04599 tuba and marimba climbing rolls.wav">,
#  <Sound: id="381178", name="Switzerland Station Chime -SBB.wav">,
#  <Sound: id="419242", name="Malletlayer.wav">,
#  <Sound: id="186501", name="keyboard2.aif">,
#  <Sound: id="394477", name="Gamepack1 -Main Horrible finish.wav">,
#  <Sound: id="395502", name="Awkward Tag">,
#  <Sound: id="25417", name="Platter Marimba.wav">,
#  <Sound: id="434085", name="Subway MTA Door Close Chime">,
#  <Sound: id="2342", name="STAB 017 mastered 16 bit.wav">,
#  <Sound: id="10430", name="gbell_7-2_pp.aif">,
#  <Sound: id="390588", name="Pan Flute 01.wav">,
#  <Sound: id="454613", name="Pan Flute Loop_carlos carty_Em_100BPM.wav">,
#  <Sound: id="444667", name="K1-Pan- D4">,
#  <Sound: id="427080", name="Zanka Note D.wav">,
#  <Sound: id="76470", name="b2_02.wav">,
#  <Sound: id="410405", name="Tin Whistle, Flutter, A (H4n).wav">,
#  <Sound: id="113685", name="Clay bird flute 1.wav">,
#  <Sound: id="427567", name="Flute">,
#  <Sound: id="107307", name="f_A.wav">,
#  <Sound: id="60067", name="fluteE2.WAV">,
#  <Sound: id="328971", name="fraseXiao.wav">,
#  <Sound: id="121067", name="75 flutes.wav">,
#  <Sound: id="121066", name="75 flutes 2.wav">,
#  <Sound: id="337980", name="98PianoFlute.wav">,
#  <Sound: id="23782", name="FluteSlap00.aif">,
#  <Sound: id="133696", name="Native American Flute - Improv 1- D minor - 90BPM DRY (20).wav">,
#  <Sound: id="27170", name="flute_2.wav">,
#  <Sound: id="427566", name="Flute staccato">,
#  <Sound: id="176865", name="flute1.wav">,
#  <Sound: id="85790", name="NATIVE FLUTE FIGURE 01.wav">,
#  <Sound: id="179061", name="sheepbone flute">,
#  <Sound: id="429848", name="DIZI FLUTE LOOP 24 120 BPM.wav">,
#  <Sound: id="328857", name="Flute_FMajScale_Oct2.wav">,
#  <Sound: id="427570", name="Flute -- a short sequence">,
#  <Sound: id="460195", name="Bamboo Flute  Quenacho Jethro Tull style Loop 4 D 132 BPM">,
#  <Sound: id="246979", name="overall quality of single note - flute - C4">,
#  <Sound: id="441067", name="21 flute">,
#  <Sound: id="257363", name="overall quality of single note - flute - C4">,
#  <Sound: id="454703", name="Chinese Flute Dizi_Loop_Carlos Carty_7_Dm_100BPM.wav">,
#  <Sound: id="390588", name="Pan Flute 01.wav">,
#  <Sound: id="247002", name="overall quality of single note - flute - G4">,
#  <Sound: id="51194", name="flute riff break.wav">,
#  <Sound: id="258199", name="overall quality of single note - flute - D4">,
#  <Sound: id="21665", name="Ocarina Loop (1).wav">,
#  <Sound: id="31511", name="1 second nose flute.WAV">,
#  <Sound: id="337923", name="12Trumpet.wav">,
#  <Sound: id="194624", name="Trumpet2.wav">,
#  <Sound: id="383152", name="sib_frullato_tromba.mp3">,
#  <Sound: id="57849", name="Valve 01.wav">,
#  <Sound: id="350416", name="Rhinoceros Trumpet Expressive 2">,
#  <Sound: id="357360", name="Trumpet - G4">,
#  <Sound: id="48223", name="trumpetC2.wav">,
#  <Sound: id="48224", name="trumpetF3.wav">,
#  <Sound: id="48225", name="trumpetG2.wav">,
#  <Sound: id="16671", name="HumanTrumpet_C.wav">,
#  <Sound: id="369912", name="trumpet-E4">,
#  <Sound: id="152575", name="Tada2.mp3">,
#  <Sound: id="70890", name="trumpet2.wav">,
#  <Sound: id="413205", name="Clean Stoccatto .mp3">,
#  <Sound: id="247172", name="overall quality of single note - trumpet - A#5">,
#  <Sound: id="441065", name="23 trumpet.wav">,
#  <Sound: id="415599", name="Tech House Trumpet">,
#  <Sound: id="89754", name="Trumpet Click.wav">,
#  <Sound: id="258107", name="overall quality of single note - trumpet - B5">,
#  <Sound: id="77707", name="solo trumpet -02in F - 90bpm.wav">,
#  <Sound: id="91343", name="A 1.wav">,
#  <Sound: id="70891", name="trumpetMetal.wav">,
#  <Sound: id="374061", name="Trumpet - staccato - A#4 (Sum_SHTrumpet_stac_A#3_v1_rr1.wav)">,
#  <Sound: id="329349", name="a7p2-trumpet.wav">,
#  <Sound: id="10678", name="baya_1.L.aif">,
#  <Sound: id="413379", name="trumpet_440Hz_44100.wav">,
#  <Sound: id="48226", name="trumpetd2.wav">,
#  <Sound: id="449070", name="Sad Trumpet.wav">,
#  <Sound: id="254049", name="Definitely a real trumpet fanfare">,
#  <Sound: id="126409", name="toy trumpet.wav">,
#  <Sound: id="337981", name="99StringsOboe.wav">,
#  <Sound: id="355076", name="Oboe - A#3">,
#  <Sound: id="355138", name="Oboe - A#3 - bad-attack-air">,
#  <Sound: id="22686", name="oboe_a_440.wav">,
#  <Sound: id="373587", name="Oboe - staccato - A#3 (Oboe_Stacc_A#2_v1_rr1_Main.wav)">,
#  <Sound: id="204179", name="oboe-A4.wav">,
#  <Sound: id="83981", name="Crumhorn note 1.wav">,
#  <Sound: id="60130", name="Cello loop 4.wav">,
#  <Sound: id="337899", name="34Cello.wav">,
#  <Sound: id="121018", name="128 cello loop 1.wav">,
#  <Sound: id="121019", name="128 cello loop 2.wav">,
#  <Sound: id="42239", name="c_s cello A3.aif">,
#  <Sound: id="195547", name="5_cello_E3.wav">,
#  <Sound: id="331742", name="Synth Cello As3">,
#  <Sound: id="246887", name="Cello - A3 - other">,
#  <Sound: id="357902", name="Cello - C2">,
#  <Sound: id="195151", name="cello_random2notes_lowhigh.wav">,
#  <Sound: id="276051", name="clarinetish.wav">,
#  <Sound: id="247989", name="overall quality of single note - cello - B3">,
#  <Sound: id="341869", name="cello slide.wav">,
#  <Sound: id="149904", name="Drunk-man-Tanya_v.wav">,
#  <Sound: id="256480", name="cello phrase">,
#  <Sound: id="372762", name="Cello Section - spiccato - A3 (spic_A2_v1_RR1.wav)">,
#  <Sound: id="6", name="cello-voice-morph.wav">,
#  <Sound: id="372710", name="Cello Section - tight pizzicato - A3 (pizzT_A2_v1_RR1.wav)">,
#  <Sound: id="380852", name="4_Fis_Gis_cello_A_string.wav">,
#  <Sound: id="149894", name="cello-1-Tanya_v.wav">,
#  <Sound: id="267712", name="Ripping Off Tape">,
#  <Sound: id="148076", name="foam pluck 03.wav">,
#  <Sound: id="148077", name="foam pluck 02.wav">,
#  <Sound: id="148078", name="foam pluck 01.wav">,
#  <Sound: id="13721", name="ostanato1.ogg">,
#  <Sound: id="8890", name="alarm1.ogg">,
#  <Sound: id="267643", name="High Pitch Shifters.wav">,
#  <Sound: id="153723", name="Violoncello  Snap-pizzicato 10">,
#  <Sound: id="153769", name="Violoncello D-4 Tenuto Vibrato">,
#  <Sound: id="121023", name="128 link strings.wav">]
